# %%
#LIBRARY IMPORTS
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import warnings
warnings.filterwarnings('ignore')

#SPLIT REGQUIRED DATA : PAID ADS
sales = pd.read_excel('totalsale.xlsx',skiprows=[0])
sales['Lead Created Date'] = pd.to_datetime(sales['Lead Created Date'])
sales['activity date'] = pd.to_datetime(sales['activity date'])
sales.sort_index(by = 'Lead Created Date',inplace=True)


start_date = '2019-1-01' #->->->->->->->->CHANGE EVERYTIME
end_date = '2019-12-31'  #->->->->->->->->CHANGE EVERYTIME
sales = sales[(sales['Lead Created Date'] > start_date) & (sales['Lead Created Date'] < end_date)]

source = {'google' : 'Google Search Ad','google-search-ad' : 'Google Search Ad','google-paid-search': 'Google Search Ad',
          'google-ad': 'Google Search Ad','Pivot-cmo-google-search-ad': 'Google Search Ad','google-search-ads': 'Google Search Ad',
          'google-search-ad,pivot-cmo-google-search-ad': 'Google Search Ad','pivot-cmo-google-search-ad': 'Google Search Ad',
          'google-search-ads':'Google Search Ad','googleindia':'Google Search Ad','google-ad-extension':'Google Search Ad',
          'googleforeign':'Google Search Ad','pivot-cmo-google-search-ad':'Google Search Ad','googleindia':'Google Search Ad',
          'googleforeign':'Google Search Ad',
          
         'Organic Search':'Organic Search',
         
         'Direct Traffic':'Direct Traffic',
         
         'Skill-lync-blog':'Skill-lync-blog',
         
         'Outbound Phone call':'Outbound Phone call',
        
         'Inbound Phone call':'Inbound Phone call',
         
         'Workshop':'Workshop','Everwebinar':'Workshop','Workshop Leads':'Workshop','Workshop Leads':'Workshop',
         
         'youtube':'YouTube Videos','youtube-workshop-videos':'YouTube Videos','youtube-videos':'YouTube Videos',
         'youtube-science-videos':'YouTube Videos','youtube-testimonial-video':'YouTube Videos',
         'youtube-daily-post':'YouTube Videos','youtube-workshop-video':'YouTube Videos', 'skill-lync-youtube':'YouTube Videos',
         'youtube-workshop-video':'YouTube Videos','career-videos':'YouTube Videos','skill-lync-youtube':'YouTube Videos',
         'skill-lync-youtube-science-video':'YouTube Videos','youtube-workshop-video':'YouTube Videos',
         
         'facebook-homepage-button':'Facebook Posts/Videos','facebook-daily-video':'Facebook Posts/Videos',
         'facebook-daily-post':'Facebook Posts/Videos','Facebook Messages':'Facebook Posts/Videos',
         
         'insta-bio':'Instagram Bio','insta-story':'Instagram Bio',
         
         'Facebook Lead Ad':'Facebook Ad','Facebook conversion ad':'Facebook Ad','Facebook-traffic-ad':'Facebook Ad',
         'fb':'Facebook Ad','social media':'Facebook Ad','Facebook':'Facebook Ad',
         'pivot cmo facebook lead ad':'Facebook Ad','pivot cmo facebook ad':'Facebook Ad',
         'Facebook ads':'Facebook Ad','DM_CFD':'Facebook Ad','DM_Design':'Facebook Ad','FBConversionAds':'Facebook Ad',
         'DM_MHEVD':'Facebook Ad','facebook-conversion-ad':'Facebook Ad','pivot-facebook-traffic-ad':'Facebook Ad',
         'Pivot Facebook Lead Ad':'Facebook Ad','Social Media':'Facebook Ad','facebook-traffic-ad':'Facebook Ad',
         'DM_FBAds':'Facebook Ad','Facebook Messages':'Facebook Ad', 'FBConversionAds':'Facebook Ad',
         
         'LinkedIn Ads':'LinkedIn Ads','LInikedIn Lead Ads':'LinkedIn Ads','LinkedIn Lead Ad':'LinkedIn Ads','linkedin-traffic-ad':'LinkedIn Ads',
         
         'LinkedIn Report':'LinkedIn Report',
         
         'linkedin-daily-post':'LinkedIn Posts','linkedin-daily-video':'LinkedIn Posts','linkedin-homepage-button':'LinkedIn Posts',
         'linkedin-post':'LinkedIn Posts','linkedin-post':'LinkedIn Posts',
          
         'Collect Chat':'Collect Chat',
         
         'Quora Ads':'Quora Ads','Quora%20Ads':'Quora Ads','quora-traffic-ad':'Quora Ads','Quora%20Ads':'Quora Ads',
          
         'skill-lync-quora':'Quora','quora':'Quora','quora-answer':'Quora','quora':'Quora','quora-answer':'Quora',
          
         'Google Display Ad':'Google Display Ad','Pay per Click Ads':'Google Display Ad','Google%20Display%20Ad':'Google Display Ad',
         'Google Display Ad,google':'Google Display Ad','Google Display Ad,google':'Google Display Ad','Google%20Display%20Ad':'Google Display Ad',
          
          
         'Kaleyra Inbound Call':'Kaleyra Inbound Call','Kaleyra Voice':'Kaleyra Inbound Call',
         
         'FreshWorld':'FreshWorld',
         
         'Monster Jobs':'Monster Jobs',
         
         'Times Jobs':'Times Jobs',
         
         'JustDial':'JustDial', 'Justdial':'JustDial',
         
         'Unknown':'Unknown','Baja Team Email':'Unknown','Referral Sites':'Unknown','Upviral':'Unknown','Test Button Website':'Unknown',
         'Employability Test':'Unknown','Tawk Live Chat':'Unknown','watsapp':'Unknown','Not Available':'Unknown','watsapp':'Unknown',
         'Tawk Live Chat':'Unknown', 'Unknown':'Unknown', 
          
         'Newspaper Ad':'Newspapaer Ad','Newspaper':'Newspapaer Ad','Newspaper+Ad':'Newspapaer Ad','Newspaper%20Ad':'Newspapaer Ad',
          
         'Customer Referral':'Customer Referral',
          
         'skill-lync-blog':'Blog',
          
         'Taboola':'Taboola',
          
         'Wisdom jobs':'Wisdom jobs',
         }

sales['Source'] = sales['Lead Source'].map(source)

sales[['Email','Lead Source','Source','Lead Created Date','activity date','Course cost']]

ps_sales = sales[(sales['Source']=='Facebook Ad')|(sales['Source']=='Google Search Ad')|(sales['Source']=='Google Display Ad')
                |(sales['Source']=='LinkedIn Ads')|(sales['Source']=='Quora Ads')]



#MARK DATA WITH THE LEAD GENERAETD DATE THROUGH THE SPREAD OF REVENUE ACROSS THE YEAR
months = ('Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec')

df= {}
df0 = {}
df1= {}
df2 ={}
df3 ={}
df4 ={}
df5 ={}
df6 ={}
df7 ={}
df8 ={}
df9 ={}
df10 ={}
df11 ={}
df12 ={}

num = np.arange(12)+1

for i, mon in zip(num,months):
    df[mon] = ps_sales[ps_sales['Lead Created Date'].dt.month == i][ps_sales['activity date'].dt.month == 1][ps_sales['activity date'].dt.year == 2019]
    df[mon]['Month'] = mon
    df0[mon] = ps_sales[ps_sales['Lead Created Date'].dt.month == i][ps_sales['activity date'].dt.month == 2][ps_sales['activity date'].dt.year == 2019]
    df0[mon]['Month'] = mon
    df1[mon] = ps_sales[ps_sales['Lead Created Date'].dt.month == i][ps_sales['activity date'].dt.month == 3][ps_sales['activity date'].dt.year == 2019]
    df1[mon]['Month'] = mon
    df2[mon] = ps_sales[ps_sales['Lead Created Date'].dt.month == i][ps_sales['activity date'].dt.month == 4][ps_sales['activity date'].dt.year == 2019]
    df2[mon]['Month'] = mon
    df3[mon] = ps_sales[ps_sales['Lead Created Date'].dt.month == i][ps_sales['activity date'].dt.month == 5][ps_sales['activity date'].dt.year == 2019]
    df3[mon]['Month'] = mon
    df4[mon] = ps_sales[ps_sales['Lead Created Date'].dt.month == i][ps_sales['activity date'].dt.month == 6][ps_sales['activity date'].dt.year == 2019]
    df4[mon]['Month'] = mon
    df5[mon] = ps_sales[ps_sales['Lead Created Date'].dt.month == i][ps_sales['activity date'].dt.month == 7][ps_sales['activity date'].dt.year == 2019]
    df5[mon]['Month'] = mon
    df6[mon] = ps_sales[ps_sales['Lead Created Date'].dt.month == i][ps_sales['activity date'].dt.month == 8][ps_sales['activity date'].dt.year == 2019]
    df6[mon]['Month'] = mon
    df7[mon] = ps_sales[ps_sales['Lead Created Date'].dt.month == i][ps_sales['activity date'].dt.month == 9][ps_sales['activity date'].dt.year == 2019]
    df7[mon]['Month'] = mon
    df8[mon] = ps_sales[ps_sales['Lead Created Date'].dt.month == i][ps_sales['activity date'].dt.month == 10][ps_sales['activity date'].dt.year == 2019]
    df8[mon]['Month'] = mon
    df9[mon] = ps_sales[ps_sales['Lead Created Date'].dt.month == i][ps_sales['activity date'].dt.month == 11][ps_sales['activity date'].dt.year == 2019]
    df9[mon]['Month'] = mon
    df10[mon] = ps_sales[ps_sales['Lead Created Date'].dt.month == i][ps_sales['activity date'].dt.month == 12][ps_sales['activity date'].dt.year == 2019]
    df10[mon]['Month'] = mon
    df11[mon] = ps_sales[ps_sales['Lead Created Date'].dt.month == i][ps_sales['activity date'].dt.month == 1][ps_sales['activity date'].dt.year == 2020]
    df11[mon]['Month'] = mon
    df12[mon] = ps_sales[ps_sales['Lead Created Date'].dt.month == i][ps_sales['activity date'].dt.month == 2][ps_sales['activity date'].dt.year == 2020]
    df12[mon]['Month'] = mon
    

LEADS_2019 = pd.concat([df['Jan'],
                        
                df0['Jan'],df0['Feb'],
                        
                df1['Jan'],df1['Feb'],df1['Mar'],
                        
                df2['Jan'],df2['Feb'],df2['Mar'],df2['Apr'],
                        
                df3['Jan'],df3['Feb'],df3['Mar'],df3['Apr'],df3['May'],
                 
                df4['Jan'],df4['Feb'],df4['Mar'],df4['Apr'],df4['May'],df4['Jun'],
                 
                df5['Jan'],df5['Feb'],df5['Mar'],df5['Apr'],df5['May'],df5['Jun'],df5['Jul'],
                                
                df5['Jan'],df5['Feb'],df5['Mar'],df5['Apr'],df5['May'],df5['Jun'],df5['Jul'],
                                df5['Aug'],
                 
                df6['Jan'],df6['Feb'],df6['Mar'],df6['Apr'],df6['May'],df6['Jun'],df6['Jul'],
                                df6['Aug'],df6['Sep'],
                        
                df7['Jan'],df7['Feb'],df7['Mar'],df7['Apr'],df7['May'],df7['Jun'],df7['Jul'],
                                df7['Aug'],df7['Sep'],df7['Oct'],
                        
                df8['Jan'],df8['Feb'],df8['Mar'],df8['Apr'],df8['May'],df8['Jun'],df8['Jul'],
                                df8['Aug'],df8['Sep'],df8['Oct'],df8['Nov'],
                 
                df9['Jan'],df9['Feb'],df9['Mar'],df9['Apr'],df9['May'],df9['Jun'],df9['Jul'],
                                df9['Aug'],df9['Sep'],df9['Oct'],df9['Nov'],df9['Dec'],
                 
                df10['Jan'],df10['Feb'],df10['Mar'],df10['Apr'],df10['May'],df10['Jun'],df10['Jul'],
                                df10['Aug'],df10['Sep'],df10['Oct'],df10['Nov'],df10['Dec'],
                 
                df11['Jan'],df11['Feb'],df11['Mar'],df11['Apr'],df11['May'],df11['Jun'],df11['Jul'],
                                df11['Aug'],df11['Sep'],df11['Oct'],df11['Nov'],df11['Dec'],
            
                df12['Jan'],df12['Feb'],df12['Mar'],df12['Apr'],df12['May'],df12['Jun'],df12['Jul'],
                                df12['Aug'],df12['Sep'],df12['Oct'],df12['Nov'],df12['Dec']
                       ])


LEADS_2019['Created on'] = LEADS_2019['activity date'].dt.month == i

for i , mon  in zip(num,months):
    LEADS_2019['Created on'][LEADS_2019['activity date'].dt.month == i]= mon

LEADS_2019['Year'] = LEADS_2019['activity date'].dt.year == 2019

YEARS = {True : 2019, False : 2020}
LEADS_2019['YEAR'] = LEADS_2019['Year'].map(YEARS)
LEADS_2019['Revenue_month'] = LEADS_2019['Created on']


LEADS_2019['Revenue_month']= LEADS_2019['Created on'].astype(str) +'-'+LEADS_2019['YEAR'].astype(str)

LEADS_2019.rename(columns={'Month': 'Lead_generated_on','Course cost':'Revenue'}, inplace=True)

leads_2019 = LEADS_2019[['Email','Source','Lead_generated_on','Revenue_month','Revenue']]


#TO DOC
leads_2019.to_excel('Revenue_realization_2019.xlsx')
